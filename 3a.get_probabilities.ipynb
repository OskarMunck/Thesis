# %% [markdown]
# # First step in pipeline
# # Get probabilities of podcasts which you want to find segments and topics of
# **Load HDBSCAN and t-SNE models and find probabilities for all sentences in a document. The output of this file will be used in the segmentation**

# %%
import os
import pickle
import hdbscan
import numpy as np
import pandas as pd
from openTSNE import TSNE
from bertopic import BERTopic
from sklearn.decomposition import PCA
from sentence_transformers import SentenceTransformer

# %%
# load PCA class object
with open('../Thesis/Final_models/pca_model_word100.pkl', 'rb') as inp:
    PCA_model = pickle.load(inp)

# %%
1-sum(PCA_model.explained_variance_ratio_)
# Out:
# 0.24606509894744488

# %%
# load t-SNE class object
with open('../Thesis/Final_models/tsne_data_word100.pkl', 'rb') as inp:
    tsne_data = pickle.load(inp)

# %%
# loop through all of the annotated transcripts and save dim reduced vectors
directory = '../Thesis/annotated_transcripts_input'

for dirpath, _, files in os.walk(directory):
    for file in files:
        episode_id = file.split('_')[0]
        path = os.path.join(dirpath, file)
        with open(path, errors='replace') as f: 
            prediction_documents = pd.read_csv(f)
            docs = prediction_documents.transcript_subset

            # embedd
            sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
            embedded_sentences = sentence_model.encode(docs)

            # reduce dimensions with PCA and t-SNE
            PCA_data = PCA_model.transform(embedded_sentences)
            print(f"{1-sum(PCA_model.explained_variance_ratio_):.2%} of the variance has been removed by PCA for transcript {episode_id}")
            tsne_prediction = tsne_data.transform(PCA_data)

            # Write transcripts to files
            save_path = '../Thesis/annotated_dimreduced/'
            name_of_file = f'dimreduced_word100_{episode_id}.npy'
            complete_path = os.path.join(save_path, name_of_file)
            np.save(complete_path, tsne_prediction)
# Out:
# 24.61% of the variance has been removed by PCA for transcript 7A7swZJL0AtFghauiGLadV
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 3.50 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.06 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 1166.6498, 50 iterations in 15.8317 sec
# Iteration  100, KL divergence 1149.5606, 50 iterations in 15.7309 sec
# Iteration  150, KL divergence 1138.6246, 50 iterations in 15.8113 sec
# Iteration  200, KL divergence 1133.7704, 50 iterations in 19.1794 sec
# Iteration  250, KL divergence 1133.1779, 50 iterations in 18.4420 sec
#    --> Time elapsed: 85.00 seconds
# 24.61% of the variance has been removed by PCA for transcript 5Sg6efUjypR4m6p9eYBXpm
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 3.98 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 5002.0866, 50 iterations in 16.8465 sec
# Iteration  100, KL divergence 4935.5814, 50 iterations in 17.0271 sec
# Iteration  150, KL divergence 4881.4342, 50 iterations in 19.4322 sec
# Iteration  200, KL divergence 4871.4089, 50 iterations in 19.8357 sec
# Iteration  250, KL divergence 4866.0062, 50 iterations in 16.1906 sec
#    --> Time elapsed: 89.33 seconds
# 24.61% of the variance has been removed by PCA for transcript 3DR5Qa40Mc17AiBYfmC29U
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 1.95 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 2883.2481, 50 iterations in 16.3683 sec
# Iteration  100, KL divergence 2838.4575, 50 iterations in 15.4698 sec
# Iteration  150, KL divergence 2828.7124, 50 iterations in 15.4101 sec
# Iteration  200, KL divergence 2827.7042, 50 iterations in 15.3562 sec
# Iteration  250, KL divergence 2825.4066, 50 iterations in 15.6487 sec
#    --> Time elapsed: 78.26 seconds
# 24.61% of the variance has been removed by PCA for transcript 0bXWB28GwN8OiqC1ykRrRX
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 1.00 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 7743.8052, 50 iterations in 16.3956 sec
# Iteration  100, KL divergence 7623.6861, 50 iterations in 16.2429 sec
# Iteration  150, KL divergence 7592.2168, 50 iterations in 15.8493 sec
# Iteration  200, KL divergence 7576.6892, 50 iterations in 15.9190 sec
# Iteration  250, KL divergence 7563.8095, 50 iterations in 15.7849 sec
#    --> Time elapsed: 80.19 seconds
# 24.61% of the variance has been removed by PCA for transcript 13NDTKL5ZGs8cb8dojW3bz
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.74 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 2847.7466, 50 iterations in 15.7208 sec
# Iteration  100, KL divergence 2797.6827, 50 iterations in 15.6523 sec
# Iteration  150, KL divergence 2780.4980, 50 iterations in 15.7082 sec
# Iteration  200, KL divergence 2776.8970, 50 iterations in 15.6336 sec
# Iteration  250, KL divergence 2776.8024, 50 iterations in 15.5851 sec
#    --> Time elapsed: 78.30 seconds
# 24.61% of the variance has been removed by PCA for transcript 4DUIcbw3EZpeYUC2mcxV0D
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.57 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 3099.0962, 50 iterations in 15.7317 sec
# Iteration  100, KL divergence 3031.2873, 50 iterations in 15.6699 sec
# Iteration  150, KL divergence 3002.3930, 50 iterations in 15.9026 sec
# Iteration  200, KL divergence 2988.2222, 50 iterations in 20.0334 sec
# Iteration  250, KL divergence 2986.6665, 50 iterations in 16.0876 sec
#    --> Time elapsed: 83.43 seconds
# 24.61% of the variance has been removed by PCA for transcript 5ts4p0QlyePWCgIB2W1wLf
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.22 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 3065.5439, 50 iterations in 18.1692 sec
# Iteration  100, KL divergence 3016.7759, 50 iterations in 17.5230 sec
# Iteration  150, KL divergence 2991.7633, 50 iterations in 18.4034 sec
# Iteration  200, KL divergence 2961.6937, 50 iterations in 19.9643 sec
# Iteration  250, KL divergence 2955.4574, 50 iterations in 15.3153 sec
#    --> Time elapsed: 89.40 seconds
# 24.61% of the variance has been removed by PCA for transcript 19W5dgUcFseQZBmcVF4coc
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 1.30 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 2483.6873, 50 iterations in 19.2145 sec
# Iteration  100, KL divergence 2455.8417, 50 iterations in 20.9370 sec
# Iteration  150, KL divergence 2438.2358, 50 iterations in 22.0558 sec
# Iteration  200, KL divergence 2429.2196, 50 iterations in 16.0914 sec
# Iteration  250, KL divergence 2419.3317, 50 iterations in 20.3618 sec
#    --> Time elapsed: 98.67 seconds
# 24.61% of the variance has been removed by PCA for transcript 3iydyD9rAb1f6rmvmgpwS4
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.43 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 5947.0107, 50 iterations in 15.8797 sec
# Iteration  100, KL divergence 5874.3060, 50 iterations in 19.6447 sec
# Iteration  150, KL divergence 5835.3217, 50 iterations in 18.4793 sec
# Iteration  200, KL divergence 5810.3344, 50 iterations in 14.6344 sec
# Iteration  250, KL divergence 5803.8851, 50 iterations in 15.1400 sec
#    --> Time elapsed: 83.78 seconds
# 24.61% of the variance has been removed by PCA for transcript 3RT2j2BG8ILNYKjxsNhfvZ
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.57 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 5003.5422, 50 iterations in 15.8390 sec
# Iteration  100, KL divergence 4926.1590, 50 iterations in 15.0223 sec
# Iteration  150, KL divergence 4895.1004, 50 iterations in 14.3286 sec
# Iteration  200, KL divergence 4878.2712, 50 iterations in 14.3219 sec
# Iteration  250, KL divergence 4871.8949, 50 iterations in 16.3186 sec
#    --> Time elapsed: 75.83 seconds
# 24.61% of the variance has been removed by PCA for transcript 4y67J0Fmgm5L7TPPsUunwo
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.32 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 3628.5673, 50 iterations in 16.5823 sec
# Iteration  100, KL divergence 3580.5906, 50 iterations in 14.3866 sec
# Iteration  150, KL divergence 3557.4878, 50 iterations in 15.6661 sec
# Iteration  200, KL divergence 3542.8548, 50 iterations in 15.2518 sec
# Iteration  250, KL divergence 3531.1912, 50 iterations in 14.7149 sec
#    --> Time elapsed: 76.60 seconds
# 24.61% of the variance has been removed by PCA for transcript 6preEOWrgR9eRr938upFgv
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.68 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 8535.1893, 50 iterations in 15.3131 sec
# Iteration  100, KL divergence 8393.8891, 50 iterations in 14.5137 sec
# Iteration  150, KL divergence 8343.3006, 50 iterations in 15.1847 sec
# Iteration  200, KL divergence 8310.3701, 50 iterations in 14.8293 sec
# Iteration  250, KL divergence 8289.4940, 50 iterations in 14.5776 sec
#    --> Time elapsed: 74.42 seconds
# 24.61% of the variance has been removed by PCA for transcript 28IWswylk2FvkebOehoCkL
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.61 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 4601.7352, 50 iterations in 14.6435 sec
# Iteration  100, KL divergence 4556.8866, 50 iterations in 14.3054 sec
# Iteration  150, KL divergence 4521.1027, 50 iterations in 15.4580 sec
# Iteration  200, KL divergence 4506.3212, 50 iterations in 15.5499 sec
# Iteration  250, KL divergence 4502.1121, 50 iterations in 15.5127 sec
#    --> Time elapsed: 75.47 seconds
# 24.61% of the variance has been removed by PCA for transcript 2Bp5vd9GAmEpZzjEtGQBFD
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.06 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 584.6553, 50 iterations in 15.5357 sec
# Iteration  100, KL divergence 581.7602, 50 iterations in 21.0956 sec
# Iteration  150, KL divergence 577.5986, 50 iterations in 16.1190 sec
# Iteration  200, KL divergence 573.8693, 50 iterations in 16.2508 sec
# Iteration  250, KL divergence 573.0531, 50 iterations in 15.2745 sec
#    --> Time elapsed: 84.28 seconds
# 24.61% of the variance has been removed by PCA for transcript 4pFaG2QLnDr95gqDQFEWoh
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.45 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 5381.6227, 50 iterations in 15.3661 sec
# Iteration  100, KL divergence 5310.2156, 50 iterations in 15.3087 sec
# Iteration  150, KL divergence 5266.2538, 50 iterations in 15.6907 sec
# Iteration  200, KL divergence 5248.4579, 50 iterations in 15.5410 sec
# Iteration  250, KL divergence 5236.9264, 50 iterations in 15.2640 sec
#    --> Time elapsed: 77.17 seconds
# 24.61% of the variance has been removed by PCA for transcript 53DrbE5nPJskpPT0PtOi9O
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.03 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 730.8146, 50 iterations in 18.7558 sec
# Iteration  100, KL divergence 729.2851, 50 iterations in 16.6766 sec
# Iteration  150, KL divergence 726.4349, 50 iterations in 16.7330 sec
# Iteration  200, KL divergence 724.3540, 50 iterations in 16.7229 sec
# Iteration  250, KL divergence 724.3471, 50 iterations in 15.9231 sec
#    --> Time elapsed: 84.81 seconds
# 24.61% of the variance has been removed by PCA for transcript 0ZGQ63222rqX5TD5ZrMmcN
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 1.76 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 8517.5353, 50 iterations in 15.9360 sec
# Iteration  100, KL divergence 8391.4761, 50 iterations in 15.9571 sec
# Iteration  150, KL divergence 8344.6786, 50 iterations in 15.4162 sec
# Iteration  200, KL divergence 8309.7799, 50 iterations in 15.6939 sec
# Iteration  250, KL divergence 8301.9010, 50 iterations in 16.2751 sec
#    --> Time elapsed: 79.28 seconds
# 24.61% of the variance has been removed by PCA for transcript 7mv5E2yb2yVQU34OiQ1vqv
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.55 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 10014.6425, 50 iterations in 15.3531 sec
# Iteration  100, KL divergence 9931.0974, 50 iterations in 15.6969 sec
# Iteration  150, KL divergence 9884.4841, 50 iterations in 16.1317 sec
# Iteration  200, KL divergence 9862.5444, 50 iterations in 15.3350 sec
# Iteration  250, KL divergence 9845.9049, 50 iterations in 15.6926 sec
#    --> Time elapsed: 78.21 seconds
# 24.61% of the variance has been removed by PCA for transcript 3p9FLEH5V5sCGHhGubaYZc
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.23 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 2187.2661, 50 iterations in 16.5730 sec
# Iteration  100, KL divergence 2164.8110, 50 iterations in 15.2599 sec
# Iteration  150, KL divergence 2164.3255, 50 iterations in 15.0294 sec
# Iteration  200, KL divergence 2162.1066, 50 iterations in 16.7219 sec
# Iteration  250, KL divergence 2158.8373, 50 iterations in 15.0219 sec
#    --> Time elapsed: 78.61 seconds
# 24.61% of the variance has been removed by PCA for transcript 1VBbCB6ja5pPdU2wrBy27N
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 1.66 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 7804.0747, 50 iterations in 16.8331 sec
# Iteration  100, KL divergence 7694.0325, 50 iterations in 17.5768 sec
# Iteration  150, KL divergence 7632.4420, 50 iterations in 17.3386 sec
# Iteration  200, KL divergence 7609.2991, 50 iterations in 15.9284 sec
# Iteration  250, KL divergence 7597.2493, 50 iterations in 16.7439 sec
#    --> Time elapsed: 84.42 seconds

# %%
# load cluster model
with open('../Thesis/Final_models/hdbscan_msize15.pkl', 'rb') as inp:
    hdbscan_model = pickle.load(inp)

# %%
# loop through all of the annotated dim reduced embeddings and save topic probability density vector
dir = '../Thesis/annotated_dimreduced'

for dirpath, _, files in os.walk(dir):
    for file in files:
        episode_id = file[:-4].split('_')[2]
        path = os.path.join(dirpath, file)
        tsne_prediction = np.load(path)

        # get probability vectors for each cluster via soft clustering
        print(f'Starting {episode_id}')
        probabilities = hdbscan.membership_vector(hdbscan_model, tsne_prediction)
        print(f'nrows: {len(probabilities)}\nncols: {len(probabilities[0])}')
        # remedy HDBSCAN problem
        inds = np.where(np.isnan(probabilities))
        probabilities[inds] = 0
        print(f"Number of nan rows: {len(set(list(inds[:][0])))} for {episode_id}\n\n")

        # save probabilities to use in downstream segmentation
        name_of_file = f'../Thesis/annotated_probabilities_msize15/proba_dens_vec_msize15_{episode_id}'
        np.save(name_of_file, probabilities)
# Out:
# Starting 4y67J0Fmgm5L7TPPsUunwo
# nrows: 270
# ncols: 2880
# Number of nan rows: 0 for 4y67J0Fmgm5L7TPPsUunwo
#
#
# Starting 3RT2j2BG8ILNYKjxsNhfvZ
# nrows: 368
# ncols: 2880
# Number of nan rows: 0 for 3RT2j2BG8ILNYKjxsNhfvZ
#
#
# Starting 3p9FLEH5V5sCGHhGubaYZc
# nrows: 187
# ncols: 2880
# Number of nan rows: 0 for 3p9FLEH5V5sCGHhGubaYZc
#
#
# Starting 5Sg6efUjypR4m6p9eYBXpm
# nrows: 379
# ncols: 2880
# Number of nan rows: 0 for 5Sg6efUjypR4m6p9eYBXpm
#
#
# Starting 28IWswylk2FvkebOehoCkL
# nrows: 351
# ncols: 2880
# Number of nan rows: 0 for 28IWswylk2FvkebOehoCkL
#
#
# Starting 3DR5Qa40Mc17AiBYfmC29U
# nrows: 223
# ncols: 2880
# Number of nan rows: 0 for 3DR5Qa40Mc17AiBYfmC29U
#
#
# Starting 0bXWB28GwN8OiqC1ykRrRX
# nrows: 563
# ncols: 2880
# Number of nan rows: 0 for 0bXWB28GwN8OiqC1ykRrRX
#
#
# Starting 4DUIcbw3EZpeYUC2mcxV0D
# nrows: 229
# ncols: 2880
# Number of nan rows: 0 for 4DUIcbw3EZpeYUC2mcxV0D
#
#
# Starting 5ts4p0QlyePWCgIB2W1wLf
# nrows: 234
# ncols: 2880
# Number of nan rows: 0 for 5ts4p0QlyePWCgIB2W1wLf
#
#
# Starting 7mv5E2yb2yVQU34OiQ1vqv
# nrows: 747
# ncols: 2880
# Number of nan rows: 0 for 7mv5E2yb2yVQU34OiQ1vqv
#
#
# Starting 53DrbE5nPJskpPT0PtOi9O
# nrows: 75
# ncols: 2880
# Number of nan rows: 0 for 53DrbE5nPJskpPT0PtOi9O
#
#
# Starting 4pFaG2QLnDr95gqDQFEWoh
# nrows: 390
# ncols: 2880
# Number of nan rows: 0 for 4pFaG2QLnDr95gqDQFEWoh
#
#
# Starting 1VBbCB6ja5pPdU2wrBy27N
# nrows: 560
# ncols: 2880
# Number of nan rows: 0 for 1VBbCB6ja5pPdU2wrBy27N
#
#
# Starting 7A7swZJL0AtFghauiGLadV
# nrows: 98
# ncols: 2880
# Number of nan rows: 0 for 7A7swZJL0AtFghauiGLadV
#
#
# Starting 13NDTKL5ZGs8cb8dojW3bz
# nrows: 224
# ncols: 2880
# Number of nan rows: 0 for 13NDTKL5ZGs8cb8dojW3bz
#
#
# Starting 0ZGQ63222rqX5TD5ZrMmcN
# nrows: 601
# ncols: 2880
# Number of nan rows: 0 for 0ZGQ63222rqX5TD5ZrMmcN
#
#
# Starting 19W5dgUcFseQZBmcVF4coc
# nrows: 191
# ncols: 2880
# Number of nan rows: 0 for 19W5dgUcFseQZBmcVF4coc
#
#
# Starting 3iydyD9rAb1f6rmvmgpwS4
# nrows: 447
# ncols: 2880
# Number of nan rows: 0 for 3iydyD9rAb1f6rmvmgpwS4
#
#
# Starting 2Bp5vd9GAmEpZzjEtGQBFD
# nrows: 53
# ncols: 2880
# Number of nan rows: 0 for 2Bp5vd9GAmEpZzjEtGQBFD
#
#
# Starting 6preEOWrgR9eRr938upFgv
# nrows: 599
# ncols: 2880
# Number of nan rows: 0 for 6preEOWrgR9eRr938upFgv

# %% [markdown]
# ### Code for individual transcript predicitons

# %%
# load dataframe of one transcript with sentences as instances
sentences = pd.read_csv('first_podcast.csv.gz', compression='gzip')
documents = sentences.transcript_subset.to_list()

# %%
# embedd
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
embedded_sentences = sentence_model.encode(documents)

# %%
# reduce dimensions with PCA and t-SNE
PCA_model = PCA(n_components = 50)
PCA_data = PCA_model.fit_transform(embedded_sentences)
print(f"{1-sum(PCA_model.explained_variance_ratio_):.2%} of the variance has been removed by PCA")

tsne_test = tsne_data.transform(PCA_data)
# Out:
# 38.88% of the variance has been removed by PCA
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 15.46 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 9553.1733, 50 iterations in 68.5026 sec
# Iteration  100, KL divergence 9385.8024, 50 iterations in 75.2073 sec
# Iteration  150, KL divergence 9315.4148, 50 iterations in 81.2504 sec
# Iteration  200, KL divergence 9280.9488, 50 iterations in 58.4335 sec
# Iteration  250, KL divergence 9266.8228, 50 iterations in 46.4842 sec
#    --> Time elapsed: 329.89 seconds

# %%
# get probability vectors for each cluster via soft clustering
probabilities = hdbscan.membership_vector(hdbscan_model, tsne_test)
print(f'nrows: {len(probabilities)}')
print(f'ncols: {len(probabilities[0])}')
# remedy for HDBSCAN problem
inds = np.where(np.isnan(probabilities))
probabilities[inds] = 0
print(f"Number of nan rows: {len(set(list(inds[:][0])))}")
# Out:
# nrows: 599
# ncols: 156
# Number of nan rows: 0

# %%
# save probabilities to use in segmentation
np.save('probabilities_new.npy', probabilities)
